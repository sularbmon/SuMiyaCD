# %%
import os
os.chdir(r"C:/Users/HP/OneDrive/Desktop/")
 
os.rename("Programming","PRACTICE")
 
print("The Directory has been successfully renamed!")

# %%
import glob
import os
from tkinter import Tk
from tkinter.filedialog import askdirectory
import csv
import pandas as pd

data = pd.read_csv("C:\\Users\\thithilab\\Desktop\\honkawa mapper.csv",index_col ='Local_ID')

cow_mapper = [list(row) for row in data.values]

count = 1
listPath = []

def listdirs(rootdir):
    global count
    renaming_path=[] 
    for file in os.listdir(rootdir):
        d = os.path.join(rootdir, file)
        if os.path.isdir(d):
            #print(file)
            renaming_path.append(int(file))
            #print('Renaming ',d ,'to', str(count))
            #os.rename(d,os.path.join(rootdir,str(count)))
            #count+=1
            #global listPath
            #listPath.append(d)
            #listdirs(d)
    #renaming_path =renaming_path.sort()
    renaming_path.sort()
    print(renaming_path)
    for path in (renaming_path):
        os_path = os.path.join(rootdir,str(path))
        to_name = ''
        try:
            to_name =  str(int(cow_mapper[count-1][0]))
        except:
            to_name =  str(cow_mapper[count-1][0])
        print('Renaming ',os_path ,'to',to_name)
        os.rename(os_path,os.path.join(rootdir,to_name))
        count+=1
        
rootdir = ''

def openFolder():
    global rootdir
    rootdir = askdirectory(title='Select Folder')
    print(rootdir)
    listPath.append(rootdir)
    root.destroy()


root = Tk()
#Button(root, text='Select Folder', command = openFolder).pack(fill=X)
openFolder()
root.mainloop()
print(rootdir)
if(rootdir is not None and rootdir is not ''):
    listdirs(rootdir)

print(listPath)
# Out:
# <>:58: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:58: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# D:/Python/SULarbmon/Python/env/yolov8_june/ultralytics/runs/segment/honkawa_3fps/fill_black_dec_2023_to_sort
# D:/Python/SULarbmon/Python/env/yolov8_june/ultralytics/runs/segment/honkawa_3fps/fill_black_dec_2023_to_sort
# C:\Users\thithilab\AppData\Local\Temp\ipykernel_36600\2205816820.py:58: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if(rootdir is not None and rootdir is not ''):
# ...

# %%
import csv
import pandas as pd

data = pd.read_csv('D:\\LamenessData\\September_6\\evening.csv',index_col ='Local_ID')

list_of_csv = [list(row) for row in data.values]

for i in range (7):
    print('from ',i+1,' to ',list_of_csv[i][0])
