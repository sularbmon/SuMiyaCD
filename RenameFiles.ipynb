# %%
import os

# %% [markdown]
# def main():
# 	i = 10001
# 	path="D:\\Python\\SULarbmon\\Python\\env\\yolov8_june\\ultralytics\\runs\\segment\honkawa_3fps\\fill_black_dec_20235\\"
# 	for filename in os.listdir(path):
# 		my_dest = "" + str(i)
# 		my_source =path + filename
# 		my_dest =path + my_dest
# 		# rename() function will
# 		# rename all the files
# 		os.rename(my_source, my_dest)
# 		i += 1
#
# # Driver Code
# if __name__ == '__main__':
# 	# Calling main() function
# 	main()

# %%
csv_file = 'example.csv'

# Writing to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the header
    writer.writerow(data[0])

    # Write the rows
    writer.writerows(data[1:])

print(f"CSV file '{csv_file}' created successfully.")

# %%
import os
import csv
test_labels = []
train_labels = []
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

def get_creation_time(path):
    return os.path.getctime(path)

def list_folders_by_creation_date(directory):
    folders = [f for f in os.listdir(directory) if os.path.isdir(os.path.join(directory, f))]
    folders_with_dates = [(folder, get_creation_time(os.path.join(directory, folder))) for folder in folders]
    sorted_folders = sorted(folders_with_dates, key=lambda x: x[1], reverse=False)
    return sorted_folders

# Replace 'your_directory_path' with the actual path to your directory
directory_path = "D:\\Python\\SULarbmon\\Python\\env\\yolov8_june\\ultralytics\\runs\\segment\honkawa_3fps\\fill_black_dec_20235\\"
sorted_folders = list_folders_by_creation_date(directory_path)

corrector = 10001
csv_data = []
for folder, creation_time in sorted_folders:
    csv_data.append((folder,corrector))
    corrector+=1
    print(f"{folder} - Created on: {creation_time}")

csv_file = 'D:\\Python\\SULarbmon\\Python\\env\\yolov8_june\\ultralytics\\runs\\segment\honkawa_3fps\\fill_black_dec_20235\\1103_blackfill_mapping.csv'

# Writing to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the header
    #writer.writerow(data[0])

    # Write the rows
    writer.writerows(csv_data)

print(f"CSV file '{csv_file}' created successfully.")
# Out:
# 10001 - Created on: 1702383750.4666917
# 10218 - Created on: 1702383752.2832186
# 10328 - Created on: 1702383770.7195609
# 10439 - Created on: 1702383773.6825612
# 10550 - Created on: 1702383776.4899693
# 10661 - Created on: 1702383779.3184943
# 10771 - Created on: 1702383781.4578664
# 10882 - Created on: 1702383783.5563357
# 10993 - Created on: 1702383785.2975812
# 10002 - Created on: 1702383787.4293923
# 10113 - Created on: 1702383789.424142
# 10130 - Created on: 1702383791.3877892
# 10141 - Created on: 1702383797.0241785
# 10152 - Created on: 1702383799.0972266
# 10163 - Created on: 1702383801.6387224
# 10174 - Created on: 1702383803.5386622
# 10185 - Created on: 1702383805.7058418
# 10196 - Created on: 1702383807.692502
# 10207 - Created on: 1702383809.99503
# 10219 - Created on: 1702383811.8649535
# 10230 - Created on: 1702383813.9017324
# 10241 - Created on: 1702383815.8301916
# 10252 - Created on: 1702383818.1057296
# 10263 - Created on: 1702383820.4311142
# ...

# %%
mapping_data = {}
def mapper():
    global mapping_data
    csv_file = 'D:\\Python\\SULarbmon\\Python\\env\\yolov8_june\\ultralytics\\runs\\segment\honkawa_3fps\\fill_black_dec_20235\\1103_blackfill_mapping.csv'

# Create a dictionary to store the data
    

    # Read the CSV file and populate the dictionary
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        header = next(reader)  # Assuming the first row contains column headers

        for row in reader:
            cattle_id = row[0]
            correct_id = int(row[1])
            mapping_data[cattle_id] = correct_id
mapper()
to_find = '10328'
#print(mapping_data)
if to_find in mapping_data:
    output = mapping_data[to_find]
    print(output)
# Out:
# 10003
